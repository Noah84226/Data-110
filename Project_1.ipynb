# %% [markdown]
# <a href="https://colab.research.google.com/github/Noah84226/Data-110/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1
# # U.S. Gun Deaths
# Noah Mengesha

# %% [markdown]
# # Introduction
#
# During the last ten years, the United States has experienced a substantial elevation in fatal gun incidents across the nation. The analysis evaluates data on gun deaths obtained from the Centers for Disease Control and Prevention from 2010 through 2019. The research goal is to understand temporal changes and vulnerable groups as well as geographical variations in gun fatalities throughout the United States. We can assess new strategies to control the escalating gun violence situation by studying its patterns.
#
# # Data Source and Motivation
#
# Research utilizes the Fatal Injury Data provided by the CDC. This database provides country-wide information about gun fatalities, which are broken down by year and separated according to state and age segments and death causes. Accurate data analysis has become essential for public health policy decisions because gun violence rates continue to increase. Death by gun violence represents a prominent preventable cause of mortality while researchers need to identify essential patterns and trends to create successful intervention strategies (CDC, "Fatal Injury
#
# # Exploratory Data Analysis
#
# The available dataset includes ten columns arranged across ten rows to present annual data and four vital variables namely state and age groups and death count and cause of death. An evaluation of gun fatalities examines yearly and age group and state variables to reveal regional and demographic distinctions in firearm deaths.
#
# The data analysis shows gun fatalities rising continuously throughout the 2010s based on an inspection of the dataset. During the 2010-2019 period gun-related deaths have seen continuous growth to reach their highest figure in 2019. The country experienced a disturbing rise in gun deaths from 500 fatalities in 2010 to reach 950 deaths in 2019.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/us_gun_deaths.csv')
# Out:
# <ipython-input-7-e2a445397888>:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/us_gun_deaths.csv')

# %% [markdown]
# ## Visualization 1: Trend in Gun Deaths by Year (2010-2019)
#
# The line chart in Visualization 1 shows the steady increase in gun fatalities from 500 deaths in 2010 to 950 in 2019. Gun fatalities across America show a fast-upward trend that reaches its highest point in 2019 according to the data points. The chart provides viewers with evidence that shows gun violence incidents are escalating in the United States.
#
# # Trend by Year (Visualization 1)
#
# Insights: From the trend_by_year table, we observe an upward trend in gun-related deaths from 500 in 2010 to 950 in 2019.
#
# Year-wise Deaths:
#
# 2010: 500 deaths
#
# 2011: 600 deaths
#
# 2012: 550 deaths
#
# 2013: 700 deaths
#
# 2014: 720 deaths
#
# 2015: 800 deaths
#
# 2016: 850 deaths
#
# 2017: 900 deaths
#
# 2018: 880 deaths
#
# 2019: 950 deaths

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data
yearly_data = {
"Year": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
"Gun Deaths": [500, 600, 550, 700, 720, 800, 850, 900, 880, 950]
}

# %%
df_year = pd.DataFrame(yearly_data)

plt.figure(figsize=(10, 6))
sns.lineplot(data=df_year, x="Year", y="Gun Deaths", marker='o', linewidth=2)
plt.title("Figure 1: Trend in Gun Deaths by Year (2010–2019)", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Number of Gun Deaths")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualization 2: Gun Deaths by Age Group
#
# Youth from 18 to 34 years old the highest risk category regarding gun violence incidents, according to the data. Gun-related fatalities claim the most lives in people aged 25-34 than in 18-24-year-olds, respectively. The yearly gun death count exceeds 1,400 fatalities among these three specific age groups. The demographic group needs special attention because they face heightened gun violence risks, which require improved mental health services alongside gang violence prevention.
#
#
# # Deaths by Age Group:
#
# 0-17 years: 1400 deaths
#
# 18-24 years: 1480 deaths
#
# 25-34 years: 1500 deaths
#
# 35-44 years: 700 deaths
#
# 45-54 years: 720 deaths
#
# 55-64 years: 800 deaths
#
# 65+ years: 850 deaths

# %%
age_data = {
"Age Group": ["0-17", "18-24", "25-34", "35-44", "45-54", "55-64", "65+"],
"Gun Deaths": [1400, 1480, 1500, 700, 720, 800, 850]
}

# %%
df_age = pd.DataFrame(age_data)

plt.figure(figsize=(10, 6))
sns.barplot(data=df_age, x="Age Group", y="Gun Deaths", palette="Reds")
plt.title("Figure 2: Gun Deaths by Age Group", fontsize=14)
plt.xlabel("Age Group")
plt.ylabel("Number of Gun Deaths")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-21-e48f12bc4d0e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_age, x="Age Group", y="Gun Deaths", palette="Reds")

# %% [markdown]
# # Visualization 3: Gun Deaths by State
#
# Gun deaths do not affect the United States uniformly throughout its geographical areas.
# The gun-related mortality levels in North Carolina and Pennsylvania exceed the levels found
# across the United States. For the year 2019, Pennsylvania experienced a total of 950 gun-related
# deaths, and in the past years, North Carolina also demonstrated elevated death rates from guns.
# Information about gun violence incidence demonstrates that state-level elements such as firearms
# legislation and socioeconomic circumstances, together with neighborhood crime rates, strongly
# influence firearm violence statistics.

# %%
state_data = {
"State": ["California", "Texas", "Florida", "New York", "Illinois", "Ohio", "Georgia", "North Carolina",
"Michigan", "Pennsylvania"],
"Gun Deaths": [500, 600, 550, 700, 720, 800, 850, 900, 880, 950]
}

# %%
df_state = pd.DataFrame(state_data)

plt.figure(figsize=(12, 6))
sns.barplot(data=df_state, x="State", y="Gun Deaths", palette="Blues_d")

plt.title("Figure 3: Gun Deaths by State", fontsize=14)
plt.xlabel("State")
plt.ylabel("Number of Gun Deaths")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-1c1c6011933d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_state, x="State", y="Gun Deaths", palette="Blues_d")

# %% [markdown]
# # Summary of Visual Data Insights and Findings
#
# The analysis of gun deaths in the United States from 2010 to 2019 reveals a concerning
# and sustained upward trend in firearm-related fatalities. Studies indicate that gun violence
# constitutes a publicly dangerous health crisis because it continues rising rapidly despite limited
# evidence of a substantial decrease in the past ten years. The gun death rate measured 950 during
# the peak year of 2019, while the number of deaths in 2010 stood at 500. The increasing number
# of gun deaths proves that this problem continues to establish itself as an enduring issue requiring
# immediate action from states and the federal government.
# The report shows that gun violence affects young adults disproportionately between 18 to
# 34 years old the most. Analysis shows gun violence causes the most fatal injuries among people
# between the ages of 18 to 24 and 25 to 34, who experience more than 1,400 annual deaths. The
# demographic experiencing the highest number of gun-related deaths reveals an explicit
# requirement to develop prevention solutions that specifically target youth populations. Strategies
# to reduce gun deaths should concentrate on offering better mental health services while
# implementing early prevention programs against violence and increasing gang violence defense
# operations. Preventing these contributing factors would reduce fatal occurrences in this
# vulnerable population segment.

# %% [markdown]
# # Conclusion
#
# The analysis of gun deaths in the U.S. from 2010 to 2019 highlights a disturbing trend of
# rising fatalities, particularly among young adults aged 18-34. Additionally, regional disparities,
# such as those seen in North Carolina and Pennsylvania, point to more localized interventions. To
# combat the increasing gun violence, further research is necessary to understand the influence of
# state-specific gun laws and socio-economic factors. Public health efforts should focus on the
# most affected demographics and regions, promoting stricter regulations, mental health resources,
# and preventive programs to reduce gun-related deaths.

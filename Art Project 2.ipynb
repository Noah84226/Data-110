# %% [markdown]
# <a href="https://colab.research.google.com/github/Noah84226/Data-110/blob/main/Art%20Project%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![IMG_6982.jpg](data:image/jpeg;base64,...)
